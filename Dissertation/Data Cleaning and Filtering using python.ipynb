# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sales-dataset/Returns.csv
# /kaggle/input/sales-dataset/Orders.csv

# %%
orders = pd.read_csv("/kaggle/input/sales-dataset/Orders.csv",encoding='ISO-8859-1')
orders.head(5)
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       1  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# 1       2  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# 2       3  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# 3       4  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# 4       5  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
#
#   Customer ID   Customer Name    Segment   City    State         Country  \
# 0    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 1    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 2    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 3    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 4    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
#
#   Region       Product ID         Category Sub-Category  \
# 0  North  OFF-ST-10000988  Office Supplies      Storage
# ...

# %%
returns = pd.read_csv("/kaggle/input/sales-dataset/Returns.csv",encoding='ISO-8859-1')
returns.head(5)
# Out:
#           Order ID Returned
# 0  ES-2015-1137137      Yes
# 1  ES-2015-1141056      Yes
# 2  ES-2015-1228490      Yes
# 3  ES-2015-1228490      Yes
# 4  ES-2015-1228490      Yes

# %%
orders.dropna()
# Out:
#       Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# 1          2  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# 2          3  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# 3          4  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# 4          5  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# ...      ...              ...         ...         ...             ...
# 9995    9996  ES-2015-3780358  16-11-2015  19-11-2015     First Class
# 9996    9997  ES-2016-5371207  25-01-2016  29-01-2016  Standard Class
# 9997    9998  ES-2016-5371207  25-01-2016  29-01-2016  Standard Class
# 9998    9999  ES-2016-5371207  25-01-2016  29-01-2016  Standard Class
# 9999   10000  ES-2016-5371207  25-01-2016  29-01-2016  Standard Class
#
#      Customer ID      Customer Name      Segment     City    State  \
# ...

# %%
orders_uk=orders[orders['Country']=='United Kingdom']
orders_uk.head(5)
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       1  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# 1       2  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# 2       3  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# 3       4  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
# 4       5  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class
#
#   Customer ID   Customer Name    Segment   City    State         Country  \
# 0    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 1    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 2    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 3    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 4    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
#
#   Region       Product ID         Category Sub-Category  \
# 0  North  OFF-ST-10000988  Office Supplies      Storage
# ...

# %%
orders_uk.shape
# Out:
# (1633, 20)

# %%
orders_uk_ids = orders_uk['Order ID'].unique()

# %%
returns_uk = returns[returns['Order ID'].isin(orders_uk_ids)]
returns_uk.shape
# Out:
# (103, 2)

# %%
orders_uk=orders_uk.drop(columns=['Row ID'])

# %%
orders_uk.head(2)
# Out:
#           Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class    AS-10045
# 1  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class    AS-10045
#
#     Customer Name    Segment   City    State         Country Region  \
# 0  Aaron Smayling  Corporate  Leeds  England  United Kingdom  North
# 1  Aaron Smayling  Corporate  Leeds  England  United Kingdom  North
#
#         Product ID         Category Sub-Category  \
# 0  OFF-ST-10000988  Office Supplies      Storage
# 1  TEC-AC-10004144       Technology  Accessories
#
#                         Product Name   Sales  Quantity  Discount  Profit
# 0             Fellowes Folders, Blue   79.20         3       0.0    39.6
# 1  SanDisk Numeric Keypad, Bluetooth  388.92         7       0.0     0.0

# %%
print(returns_uk)
# Out:
#             Order ID Returned
# 23   ES-2015-3106999      Yes
# 24   ES-2015-3106999      Yes
# 28   ES-2015-3249098      Yes
# 41   ES-2015-4351366      Yes
# 42   ES-2015-4351366      Yes
# ..               ...      ...
# 578  IT-2017-1498487      Yes
# 606  IT-2018-1082723      Yes
# 607  IT-2018-1082723      Yes
# 617  IT-2018-2508683      Yes
# 618  IT-2018-2508683      Yes
#
# [103 rows x 2 columns]

# %%
returns_uk = returns_uk.drop_duplicates()

# %%
returns_uk.shape
# Out:
# (47, 2)

# %%
orders_uk['Proft Margin'] = orders_uk['Profit'] / orders_uk['Sales'] *100

# %%
orders_uk.head(5)
# Out:
#           Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class    AS-10045
# 1  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class    AS-10045
# 2  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class    AS-10045
# 3  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class    AS-10045
# 4  ES-2018-1311038  07-02-2018  11-02-2018  Standard Class    AS-10045
#
#     Customer Name    Segment   City    State         Country Region  \
# 0  Aaron Smayling  Corporate  Leeds  England  United Kingdom  North
# 1  Aaron Smayling  Corporate  Leeds  England  United Kingdom  North
# 2  Aaron Smayling  Corporate  Leeds  England  United Kingdom  North
# 3  Aaron Smayling  Corporate  Leeds  England  United Kingdom  North
# 4  Aaron Smayling  Corporate  Leeds  England  United Kingdom  North
#
#         Product ID         Category Sub-Category  \
# 0  OFF-ST-10000988  Office Supplies      Storage
# ...

# %%
orders_uk.to_csv("/kaggle/working/Orders_UK.csv",index=False)
returns_uk.to_csv("/kaggle/working/Returns_UK.csv",index=False)
